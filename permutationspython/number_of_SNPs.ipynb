# %%
# We plot the number of SNPs across the genome

# %%
import pandas as pd

sign_SNPs_df = pd.read_csv("signSNP_number.csv", index_col=0)

# %%
sign_SNPs_df
# Out:
#                                     Chrom1  Chrom2  Chrom3  Chrom4  Chrom5  \
# 3_prime_UTR_variant                      9       2       4       4       5
# 5_prime_UTR_variant                      6       1       2       1       1
# NMD_transcript_variant                  16      28      29      28      22
# coding_sequence_variant                  0       0       0       0       0
# downstream_gene_variant                 61      49      32      18      31
# incomplete_terminal_codon_variant        0       0       0       0       0
# intergenic_variant                      52      32      37      44      92
# intron_variant                         157     135     128      73     114
# mature_miRNA_variant                     0       0       0       0       0
# missense_variant                         4       1       2       5       1
# non_coding_transcript_exon_variant       9       5       3       4       5
# non_coding_transcript_variant          100      95      66      46      87
# splice_acceptor_variant                  0       0       0       0       0
# splice_donor_variant                     0       1       0       0       0
# splice_region_variant                    0       1       0       0       0
# start_lost                               0       0       0       0       0
# stop_gained                              0       0       0       1       0
# stop_lost                                0       0       0       0       0
# stop_retained_variant                    0       0       0       0       0
# synonymous_variant                       3       0       4       0       0
# upstream_gene_variant                   64      35      43      21      28
# Total                                  481     385     350     245     386
#
#                                     Chrom6  Chrom7  Chrom8  Chrom9  Chrom10  \
# 3_prime_UTR_variant                      3       5       5       1        1
# 5_prime_UTR_variant                      0       1       1       1        0
# NMD_transcript_variant                   4      12      35       3       11
# coding_sequence_variant                  0       0       0       0        0
# downstream_gene_variant                 35      46      82       6       24
# incomplete_terminal_codon_variant        0       0       0       0        0
# intergenic_variant                      81      44     118       8       69
# intron_variant                          91     103     272      29      138
# mature_miRNA_variant                     0       0       0       0        0
# missense_variant                         0       2       3       5        4
# non_coding_transcript_exon_variant       3      13      17       2        4
# non_coding_transcript_variant           29      55     163      13       64
# splice_acceptor_variant                  0       0       0       0        0
# splice_donor_variant                     0       0       0       0        0
# splice_region_variant                    1       1       1       1        0
# start_lost                               0       0       0       0        0
# stop_gained                              0       0       0       0        0
# stop_lost                                0       0       0       0        0
# stop_retained_variant                    0       0       0       0        0
# synonymous_variant                       0       3       1       0        1
# upstream_gene_variant                   33      48      84       7       22
# Total                                  280     333     782      76      338
#
#                                     ...  Chrom14  Chrom15  Chrom16  Chrom17  \
# 3_prime_UTR_variant                 ...        1        1        8        7
# 5_prime_UTR_variant                 ...        1        1        2        4
# NMD_transcript_variant              ...        5       20       35       40
# coding_sequence_variant             ...        0        0        0        0
# downstream_gene_variant             ...       13       24       46       55
# incomplete_terminal_codon_variant   ...        0        0        0        0
# intergenic_variant                  ...        2       19       22       19
# intron_variant                      ...       19       67      122       93
# mature_miRNA_variant                ...        0        0        0        0
# missense_variant                    ...        2        0        3        0
# non_coding_transcript_exon_variant  ...        1        1        7        9
# non_coding_transcript_variant       ...       14       43       56       57
# splice_acceptor_variant             ...        0        0        0        0
# splice_donor_variant                ...        0        0        1        0
# splice_region_variant               ...        0        0        1        0
# start_lost                          ...        0        0        0        0
# stop_gained                         ...        0        1        0        0
# stop_lost                           ...        0        0        0        0
# stop_retained_variant               ...        0        0        0        0
# synonymous_variant                  ...        1        1        3        2
# upstream_gene_variant               ...       10       29       51       53
# Total                               ...       69      207      357      339
#
#                                     Chrom18  Chrom19  Chrom20  Chrom21  \
# 3_prime_UTR_variant                       0        4        4        0
# 5_prime_UTR_variant                       0        3        0        0
# NMD_transcript_variant                    4       20       12        0
# coding_sequence_variant                   0        0        0        0
# downstream_gene_variant                   1       32       23        2
# incomplete_terminal_codon_variant         0        0        0        0
# intergenic_variant                       23        7       30        9
# intron_variant                           25       59       86        8
# mature_miRNA_variant                      0        0        0        0
# missense_variant                          0        5        2        1
# non_coding_transcript_exon_variant        3        8        4        1
# non_coding_transcript_variant            18       38       42        7
# splice_acceptor_variant                   0        0        0        0
# splice_donor_variant                      0        0        0        0
# splice_region_variant                     0        0        0        0
# start_lost                                0        0        0        0
# stop_gained                               0        0        0        0
# stop_lost                                 0        0        0        0
# stop_retained_variant                     0        0        0        0
# synonymous_variant                        0        6        1        0
# upstream_gene_variant                     4       26       31        7
# Total                                    78      208      235       35
#
#                                     Chrom22   Total
# 3_prime_UTR_variant                       0    75.0
# 5_prime_UTR_variant                       0    34.0
# NMD_transcript_variant                    0   412.0
# coding_sequence_variant                   0     0.0
# downstream_gene_variant                   2   731.0
# incomplete_terminal_codon_variant         0     0.0
# intergenic_variant                        3   852.0
# intron_variant                            4  2057.0
# mature_miRNA_variant                      0     0.0
# missense_variant                          0    48.0
# non_coding_transcript_exon_variant        0   110.0
# non_coding_transcript_variant             1  1195.0
# splice_acceptor_variant                   0     0.0
# splice_donor_variant                      0     2.0
# splice_region_variant                     0     7.0
# start_lost                                0     0.0
# stop_gained                               0     2.0
# stop_lost                                 0     0.0
# stop_retained_variant                     0     0.0
# synonymous_variant                        0    32.0
# upstream_gene_variant                     5   751.0
# Total                                    15     NaN
#
# [22 rows x 23 columns]

# %%
#!pip install heatmapz
# Out:
# Collecting heatmapz
#   Downloading heatmapz-0.0.4-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: matplotlib>=3.0.3 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from heatmapz) (3.5.0)
# Requirement already satisfied: pandas in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from heatmapz) (1.4.1)
# Requirement already satisfied: seaborn in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from heatmapz) (0.11.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from matplotlib>=3.0.3->heatmapz) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from matplotlib>=3.0.3->heatmapz) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from matplotlib>=3.0.3->heatmapz) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from matplotlib>=3.0.3->heatmapz) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from matplotlib>=3.0.3->heatmapz) (21.3)
# Requirement already satisfied: cycler>=0.10 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from matplotlib>=3.0.3->heatmapz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from matplotlib>=3.0.3->heatmapz) (4.25.0)
# Requirement already satisfied: numpy>=1.17 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from matplotlib>=3.0.3->heatmapz) (1.20.3)
# Requirement already satisfied: six>=1.5 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->heatmapz) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from pandas->heatmapz) (2021.3)
# Requirement already satisfied: scipy>=1.0 in /gpfs/igmmfs01/eddie/GWAS-annotations/annotation-env/lib/python3.9/site-packages (from seaborn->heatmapz) (1.7.3)
# Installing collected packages: heatmapz
# Successfully installed heatmapz-0.0.4

# %%
import seaborn as sns
import matplotlib as plt

# %%
sns.set(rc = {'figure.figsize':(15,15)})
sns.heatmap(sign_SNPs_df, cmap="PuRd", center=1000)
# Out:
# <AxesSubplot:>

# %%
ValueError: 'hu' is not a valid value for name; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'
